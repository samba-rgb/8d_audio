# %%
import urllib.request

# %%
# !pip install pytube
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 56 kB 5.2 MB/s
# ...

# %%
# !pip install librosa
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import librosa
audio_data = '/content/srivennela.mp3'
x , sr = librosa.load(audio_data,sr=44100)
print(type(x), type(sr))

# %%
librosa.load(audio_data, sr=441000)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import librosa.display
plt.figure(figsize=(24, 10))
librosa.display.waveplot(x, sr=sr)

# %%
import librosa
audio_data = '/content/srivennela_1.mp3'
x1 , sr = librosa.load(audio_data,sr=44100)
# Out:
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import librosa.display
plt.figure(figsize=(24, 10))
librosa.display.waveplot(x1, sr=sr)

# %%
y = x -x1
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-22-a3d3ef67a9e6> in <module>()
# ----> 1 y = x -x1
#
# ValueError: operands could not be broadcast together with shapes (11796481,) (11799044,)

# %%
# !pip install pydub

# %%
# import required modules
from os import path
from pydub import AudioSegment

# assign files
input_file = "/content/mudhalnee.mp3"
output_file = "/content/mudhalnee.wav"

# convert mp3 file to wav file
sound = AudioSegment.from_mp3(input_file)
sound.export(output_file, format="wav")

# %%
# import required modules
from os import path
from pydub import AudioSegment

# assign files
input_file = "/content/srivennela.mp3"
output_file = "/content/srivennela.wav"

# convert mp3 file to wav file
sound = AudioSegment.from_mp3(input_file)
sound.export(output_file, format="wav")
# import required modules
from os import path
from pydub import AudioSegment

# assign files
input_file = "/content/srivennela_1.mp3"
output_file = "/content/srivennela_1.wav"

# convert mp3 file to wav file
sound = AudioSegment.from_mp3(input_file)
sound.export(output_file, format="wav")
# Out:
# <_io.BufferedRandom name='/content/srivennela_1.wav'>

# %%
import wave
wav_obj = wave.open('/content/srivennela.wav', 'rb')

# %%
sample_freq = wav_obj.getframerate()
sample_freq
# Out:
# 48000

# %%
n_samples = wav_obj.getnframes()
n_samples
# Out:
# 12839707

# %%
t_audio = n_samples/sample_freq
t_audio
# Out:
# 267.49389583333334

# %%
n_channels = wav_obj.getnchannels()
n_channels
# Out:
# 2

# %%
signal_wave = wav_obj.readframes(n_samples)

# %%
import numpy as np
signal_array = np.frombuffer(signal_wave, dtype=np.int16)

# %%
l_channel = signal_array[0::2]
r_channel = signal_array[1::2]

# %%
times = np.linspace(0, n_samples/sample_freq, num=n_samples)

# %%
times[-1]
# Out:
# 267.49389583333334

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(15, 5))
plt.plot(times, l_channel)
plt.title('Left Channel')
plt.ylabel('Signal Value')
plt.xlabel('Time (s)')
plt.xlim(0, t_audio)
plt.show()

# %%
wav_obj = wave.open('/content/srivennela.wav', 'rb')
sample_freq = wav_obj.getframerate()

n_samples = wav_obj.getnframes()

t_audio = n_samples/sample_freq

n_channels = wav_obj.getnchannels()

signal_wave = wav_obj.readframes(n_samples)
signal_array = np.frombuffer(signal_wave, dtype=np.int16)
l_channel = signal_array[0::2]
r_channel = signal_array[1::2]
times = np.linspace(0, n_samples/sample_freq, num=n_samples)
import matplotlib.pyplot as plt
plt.figure(figsize=(15, 5))
plt.plot(times, l_channel)
plt.title('Left Channel')
plt.ylabel('Signal Value')
plt.xlabel('Time (s)')
plt.xlim(0, t_audio)
plt.show()
import matplotlib.pyplot as plt
plt.figure(figsize=(15, 5))
plt.plot(times, r_channel)
plt.title('right Channel')
plt.ylabel('Signal Value')
plt.xlabel('Time (s)')
plt.xlim(0, t_audio)
plt.show()

# %%
wav_obj = wave.open('/content/srivennela_1.wav', 'rb')
sample_freq = wav_obj.getframerate()

n_samples = wav_obj.getnframes()

t_audio = n_samples/sample_freq

n_channels = wav_obj.getnchannels()

signal_wave = wav_obj.readframes(n_samples)
signal_array = np.frombuffer(signal_wave, dtype=np.int16)
l_channel = signal_array[0::2]
r_channel = signal_array[1::2]
times = np.linspace(0, n_samples/sample_freq, num=n_samples)
import matplotlib.pyplot as plt
plt.figure(figsize=(15, 5))
plt.plot(times, l_channel)
plt.title('Left Channel')
plt.ylabel('Signal Value')
plt.xlabel('Time (s)')
plt.xlim(0, t_audio)
plt.show()
import matplotlib.pyplot as plt
plt.figure(figsize=(15, 5))
plt.plot(times, r_channel)
plt.title('right Channel')
plt.ylabel('Signal Value')
plt.xlabel('Time (s)')
plt.xlim(0, t_audio)
plt.show()

# %%
import math

# %%
wav_obj = wave.open('/content/srivennela.wav', 'rb')
sample_freq = wav_obj.getframerate()

n_samples = wav_obj.getnframes()

t_audio = n_samples/sample_freq

n_channels = wav_obj.getnchannels()

signal_wave = wav_obj.readframes(n_samples)
signal_array = np.frombuffer(signal_wave, dtype=np.int16)
l_channel = signal_array[0::2]
r_channel = signal_array[1::2]
times = np.linspace(0, n_samples/sample_freq, num=n_samples)
import matplotlib.pyplot as plt


mock = signal_array.copy()
temp = mock[0::2]
temp2 = mock[1::2]
k  = []
for i in range(len(temp)):
  k.append(temp[i]*(sining(times[i])))

plt.figure(figsize=(15, 5))
plt.plot(times, k)
plt.title('k Channel')
plt.ylabel('Signal Value')
plt.xlabel('Time (s)')
plt.xlim(0, t_audio)
plt.show()

k2 = []

for i in range(len(temp2)):
  k2.append(temp2[i]*(cosing(times[i])))

plt.figure(figsize=(15, 5))
plt.plot(times, k2)
plt.title('k2 Channel')
plt.ylabel('Signal Value')
plt.xlabel('Time (s)')
plt.xlim(0, t_audio)
plt.show()

# %%
def sining(tim):
  if abs(math.sin(22*math.pi*tim/(267.49389583333334))) <0.2:
    return 0.2
  else:
    return abs(math.sin(22*math.pi*tim/(267.49389583333334)))

# %%
def cosing(tim):
  if abs(math.cos(22*math.pi*tim/(267.49389583333334))) <0.2:
    return 0.2
  else:
    return abs(math.cos(22*math.pi*tim/(267.49389583333334)))

# %%
mock[0::2] = k
mock[1::2] = k2

# %%
plt.figure(figsize=(15, 5))
plt.plot(times, mock[0::2])
plt.title('trail2 Channel')
plt.ylabel('Signal Value')
plt.xlabel('Time (s)')
plt.xlim(0, t_audio)
plt.show()

# %%
mock_buffer = mock.tobytes()

# %%
with wave.open("/content/srivennela.wav", "rb") as handle:
    params = handle.getparams()
    # only read the first 10 seconds of audio
    frames = handle.readframes(12839707)
    print(handle.tell())
print(params)
with wave.open("/content/srivennela_1.wav", "rb") as handle:
    params = handle.getparams()
    # only read the first 10 seconds of audio
    frames = handle.readframes(12839707)
    print(handle.tell())
print(params)
# Out:
# 12839707
# _wave_params(nchannels=2, sampwidth=2, framerate=48000, nframes=12839707, comptype='NONE', compname='not compressed')
# 12839707
# _wave_params(nchannels=2, sampwidth=2, framerate=48000, nframes=12842496, comptype='NONE', compname='not compressed')

# %%
import wave

with wave.open("/content/srivennela.wav", "rb") as handle:
    params = handle.getparams()
    # only read the first 10 seconds of audio
    frames = handle.readframes(12839707)
    print(handle.tell())

print(params)
params = list(params)
params[3] = len(frames)
print(params)

with wave.open("/content/mock1.wav", "wb") as handle:
    handle.setparams(params)
    handle.writeframes(mock_buffer)
# Out:
# 12839707
# _wave_params(nchannels=2, sampwidth=2, framerate=48000, nframes=12839707, comptype='NONE', compname='not compressed')
# [2, 2, 48000, 51358828, 'NONE', 'not compressed']

# %%
import wave

# %%
import numpy as np

# %%
# import required modules
from os import path
from pydub import AudioSegment

# assign files
input_file = "/content/ashok_kalavathi.mp3"
output_file = "/content/ashok_kalavathi.wav"

# convert mp3 file to wav file
sound = AudioSegment.from_mp3(input_file)
sound.export(output_file, format="wav")
wav_obj = wave.open('/content/ashok_kalavathi.wav', 'rb')
sample_freq = wav_obj.getframerate()

n_samples = wav_obj.getnframes()

t_audio = n_samples/sample_freq

n_channels = wav_obj.getnchannels()

signal_wave = wav_obj.readframes(n_samples)
signal_array = np.frombuffer(signal_wave, dtype=np.int16)
l_channel = signal_array[0::2]
r_channel = signal_array[1::2]
times = np.linspace(0, n_samples/sample_freq, num=n_samples)
import matplotlib.pyplot as plt
def sining(tim,times):
  if abs(math.sin(22*math.pi*tim/(times[-1]))) <0.2:
    return 0.2
  else:
    return abs(math.sin(22*math.pi*tim/(times[-1])))
def cosing(tim,times):
  if abs(math.cos(22*math.pi*tim/(times[-1]))) <0.2:
    return 0.2
  else:
    return abs(math.cos(22*math.pi*tim/(times[-1])))

mock = signal_array.copy()
temp = mock[0::2]
temp2 = mock[1::2]
k  = []
for i in range(len(temp)):
  k.append(temp[i]*(sining(times[i],times)))

plt.figure(figsize=(15, 5))
plt.plot(times, k)
plt.title('k Channel')
plt.ylabel('Signal Value')
plt.xlabel('Time (s)')
plt.xlim(0, t_audio)
plt.show()

k2 = []

for i in range(len(temp2)):
  k2.append(temp2[i]*(cosing(times[i],times)))


plt.figure(figsize=(15, 5))
plt.plot(times, k2)
plt.title('k2 Channel')
plt.ylabel('Signal Value')
plt.xlabel('Time (s)')
plt.xlim(0, t_audio)
plt.show()
mock[0::2] = k
mock[1::2] = k2
import wave
mock_buffer = mock.tobytes()
with wave.open("/content/ashok_kalavathi.wav", "rb") as handle:
    params = handle.getparams()
    # only read the first 10 seconds of audio
    frames = handle.readframes(12839707)
    print(handle.tell())

print(params)
params = list(params)
params[3] = len(frames)
print(params)

with wave.open("/content/mock4.wav", "wb") as handle:
    handle.setparams(params)
    handle.writeframes(mock_buffer)
# Out:
# 12194816
# _wave_params(nchannels=2, sampwidth=2, framerate=48000, nframes=12194816, comptype='NONE', compname='not compressed')
# [2, 2, 48000, 48779264, 'NONE', 'not compressed']

# %%
import math

# %%
# import required modules
from os import path
from pydub import AudioSegment

# assign files
input_file = "/content/kalavathi_1.mp3"
output_file = "/content/kalavathi_1.wav"

# convert mp3 file to wav file
sound = AudioSegment.from_mp3(input_file)
sound.export(output_file, format="wav")
# Out:
# <_io.BufferedRandom name='/content/kalavathi_1.wav'>

# %%
wav_obj = wave.open('/content/kalavathi_1.wav', 'rb')
sample_freq = wav_obj.getframerate()

n_samples = wav_obj.getnframes()

t_audio = n_samples/sample_freq

n_channels = wav_obj.getnchannels()

signal_wave = wav_obj.readframes(n_samples)
signal_array = np.frombuffer(signal_wave, dtype=np.int16)
l_channel = signal_array[0::2]
r_channel = signal_array[1::2]
times = np.linspace(0, n_samples/sample_freq, num=n_samples)
import matplotlib.pyplot as plt
plt.figure(figsize=(15, 5))
plt.plot(times, l_channel)
plt.title('Left Channel')
plt.ylabel('Signal Value')
plt.xlabel('Time (s)')
plt.xlim(0, t_audio)
plt.show()
import matplotlib.pyplot as plt
plt.figure(figsize=(15, 5))
plt.plot(times, r_channel)
plt.title('right Channel')
plt.ylabel('Signal Value')
plt.xlabel('Time (s)')
plt.xlim(0, t_audio)
plt.show()

# %%
# !pip install pydub
import wave
import math
import numpy as np
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# import required modules
from os import path
from pydub import AudioSegment

# assign files
input_file = "/content/song2.mp3"
output_file = "/content/song2.wav"

# convert mp3 file to wav file
sound = AudioSegment.from_mp3(input_file)
sound.export(output_file, format="wav")
wav_obj = wave.open('/content/song2.wav', 'rb')
sample_freq = wav_obj.getframerate()

n_samples = wav_obj.getnframes()

t_audio = n_samples/sample_freq

n_channels = wav_obj.getnchannels()

signal_wave = wav_obj.readframes(n_samples)
signal_array = np.frombuffer(signal_wave, dtype=np.int16)
l_channel = signal_array[0::2]
r_channel = signal_array[1::2]
times = np.linspace(0, n_samples/sample_freq, num=n_samples)
import matplotlib.pyplot as plt
def sining(tim,times):
  if abs(math.sin(11*math.pi*tim/(times[-1]))) <0.2:
    return 0.2
  else:
    return abs(math.sin(11*math.pi*tim/(times[-1])))
def cosing(tim,times):
  if abs(math.cos(11*math.pi*tim/(times[-1]))) <0.2:
    return 0.2
  else:
    return abs(math.cos(11*math.pi*tim/(times[-1])))

mock = signal_array.copy()
temp = mock[0::2]
temp2 = mock[1::2]
k  = []
for i in range(len(temp)):
  k.append(temp[i]*(sining(times[i],times)))

plt.figure(figsize=(15, 5))
plt.plot(times, k)
plt.title('k Channel')
plt.ylabel('Signal Value')
plt.xlabel('Time (s)')
plt.xlim(0, t_audio)
plt.show()

k2 = []

for i in range(len(temp2)):
  k2.append(temp2[i]*(cosing(times[i],times)))


plt.figure(figsize=(15, 5))
plt.plot(times, k2)
plt.title('k2 Channel')
plt.ylabel('Signal Value')
plt.xlabel('Time (s)')
plt.xlim(0, t_audio)
plt.show()
mock[0::2] = k
mock[1::2] = k2
import wave
mock_buffer = mock.tobytes()
with wave.open("/content/song2.wav", "rb") as handle:
    params = handle.getparams()
    # only read the first 10 seconds of audio
    frames = handle.readframes(12839707)
    print(handle.tell())

print(params)
params = list(params)
params[3] = len(frames)
print(params)

with wave.open("/content/song2_8d.wav", "wb") as handle:
    handle.setparams(params)
    handle.writeframes(mock_buffer)
# Out:
# 3859456
# _wave_params(nchannels=2, sampwidth=2, framerate=48000, nframes=3859456, comptype='NONE', compname='not compressed')
# [2, 2, 48000, 15437824, 'NONE', 'not compressed']

# %%
# !pip install youtube_dl
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 1.9 MB 28.2 MB/s
# ...

# %%
import youtube_dl
def run():
    video_url = input("please enter youtube video url:")
    video_info = youtube_dl.YoutubeDL().extract_info(
        url = video_url,download=False
    )
    filename = f"{video_info['title']}.mp3"
    options={
        'format':'bestaudio/best',
        'keepvideo':False,
        'outtmpl':filename,
    }

    with youtube_dl.YoutubeDL(options) as ydl:
        ydl.download([video_info['webpage_url']])

    print("Download complete... {}".format(filename))

if __name__=='__main__':
    run()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-9-1a8a4dc12cac> in <module>()
# ----> 1 import youtube_dl
#       2 def run():
#       3     video_url = input("please enter youtube video url:")
#       4     video_info = youtube_dl.YoutubeDL().extract_info(
#       5         url = video_url,download=False
#
# ModuleNotFoundError: No module named 'youtube_dl'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
import wave

# %%
# !pip install pydub
import math
import numpy as np
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# import required modules
from os import path
from pydub import AudioSegment

# assign files
input_file = "/content/mudhal_nee.mp3"
output_file = "/content/mudhal_nee.wav"

# convert mp3 file to wav file
sound = AudioSegment.from_mp3(input_file)
sound.export(output_file, format="wav")
wav_obj = wave.open('/content/mudhal_nee.wav', 'rb')
sample_freq = wav_obj.getframerate()

n_samples = wav_obj.getnframes()

t_audio = n_samples/sample_freq

n_channels = wav_obj.getnchannels()

signal_wave = wav_obj.readframes(n_samples)
signal_array = np.frombuffer(signal_wave, dtype=np.int16)
l_channel = signal_array[0::2]
r_channel = signal_array[1::2]
times = np.linspace(0, n_samples/sample_freq, num=n_samples)
import matplotlib.pyplot as plt
def sining(tim,times):
  if abs(math.sin(11*math.pi*tim/(times[-1]))) <0.2:
    return 0.2
  else:
    return abs(math.sin(11*math.pi*tim/(times[-1])))
def cosing(tim,times):
  if abs(math.cos(11*math.pi*tim/(times[-1]))) <0.2:
    return 0.2
  else:
    return abs(math.cos(11*math.pi*tim/(times[-1])))

mock = signal_array.copy()
temp = mock[0::2]
temp2 = mock[1::2]
k  = []
for i in range(len(temp)):
  k.append(temp[i]*(sining(times[i],times)))

plt.figure(figsize=(15, 5))
plt.plot(times, k)
plt.title('k Channel')
plt.ylabel('Signal Value')
plt.xlabel('Time (s)')
plt.xlim(0, t_audio)
plt.show()

k2 = []

for i in range(len(temp2)):
  k2.append(temp2[i]*(cosing(times[i],times)))


plt.figure(figsize=(15, 5))
plt.plot(times, k2)
plt.title('k2 Channel')
plt.ylabel('Signal Value')
plt.xlabel('Time (s)')
plt.xlim(0, t_audio)
plt.show()
mock[0::2] = k
mock[1::2] = k2
import wave
mock_buffer = mock.tobytes()
with wave.open("/content/mudhal_nee.wav", "rb") as handle:
    params = handle.getparams()
    # only read the first 10 seconds of audio
    frames = handle.readframes(len(times))
    print(handle.tell())

print(params)
params = list(params)
params[3] = len(frames)
print(params)

with wave.open("/content/mudhal_nee_8d2.wav", "wb") as handle:
    handle.setparams(params)
    handle.writeframes(mock_buffer)

# %%
from pydub import AudioSegment
from pydub.playback import play

#read wav file to an audio-segment
song = AudioSegment.from_wav("/content/song2_8d.wav")

#export audio segment to mp3
song.export("/content/song2_8d3.mp3", format="mp3")
# Out:
# <_io.BufferedRandom name='/content/song2_8d3.mp3'>

# %%
# import required modules
from os import path
from pydub import AudioSegment

# assign files
input_file = "/content/shristi.mp3"
output_file = "/content/shristi.wav"

# convert mp3 file to wav file
sound = AudioSegment.from_mp3(input_file)
sound.export(output_file, format="wav")
wav_obj = wave.open('/content/shristi.wav', 'rb')
sample_freq = wav_obj.getframerate()

n_samples = wav_obj.getnframes()

t_audio = n_samples/sample_freq

n_channels = wav_obj.getnchannels()

signal_wave = wav_obj.readframes(n_samples)
signal_array = np.frombuffer(signal_wave, dtype=np.int16)
l_channel = signal_array[0::2]
r_channel = signal_array[1::2]
times = np.linspace(0, n_samples/sample_freq, num=n_samples)
import matplotlib.pyplot as plt
def sining(tim,times):
  if abs(math.sin(11*math.pi*tim/(times[-1]))) <0.2:
    return 0.2
  else:
    return abs(math.sin(11*math.pi*tim/(times[-1])))
def cosing(tim,times):
  if abs(math.cos(11*math.pi*tim/(times[-1]))) <0.2:
    return 0.2
  else:
    return abs(math.cos(11*math.pi*tim/(times[-1])))

mock = signal_array.copy()
temp = mock[0::2]
temp2 = mock[1::2]
k  = []
for i in range(len(temp)):
  k.append(temp[i]*(sining(times[i],times)))

plt.figure(figsize=(15, 5))
plt.plot(times, k)
plt.title('k Channel')
plt.ylabel('Signal Value')
plt.xlabel('Time (s)')
plt.xlim(0, t_audio)
plt.show()

k2 = []

for i in range(len(temp2)):
  k2.append(temp2[i]*(cosing(times[i],times)))


plt.figure(figsize=(15, 5))
plt.plot(times, k2)
plt.title('k2 Channel')
plt.ylabel('Signal Value')
plt.xlabel('Time (s)')
plt.xlim(0, t_audio)
plt.show()
mock[0::2] = k
mock[1::2] = k2
import wave
mock_buffer = mock.tobytes()
with wave.open("/content/shristi.wav", "rb") as handle:
    params = handle.getparams()
    # only read the first 10 seconds of audio
    frames = handle.readframes(len(times))
    print(handle.tell())

print(params)
params = list(params)
params[3] = len(frames)
print(params)

with wave.open("/content/shristi_8d2.wav", "wb") as handle:
    handle.setparams(params)
    handle.writeframes(mock_buffer)

# %%
# !pip install youtube_dl
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !sudo apt-get install ffmpeg
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# ffmpeg is already the newest version (7:3.4.8-0ubuntu0.2).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'sudo apt autoremove' to remove it.
# 0 upgraded, 0 newly installed, 0 to remove and 45 not upgraded.

# %%
import youtube_dl
def run():
    video_url = input("please enter youtube video url:")
    video_info = youtube_dl.YoutubeDL().extract_info(
        url = video_url,download=False
    )
    filename = f"{video_info['title']}.mp3"
    options={
        'format':'bestaudio/best',
        'keepvideo':False,
        'outtmpl':filename,
    }

    with youtube_dl.YoutubeDL(options) as ydl:
        ydl.download([video_info['webpage_url']])

    print("Download complete... {}".format(filename))

if __name__=='__main__':
    run()
# Out:
# please enter youtube video url:https://www.youtube.com/watch?v=W1sTXEDRCx4
# [youtube] W1sTXEDRCx4: Downloading webpage
# [youtube] W1sTXEDRCx4: Downloading player 966d033c
# [youtube] W1sTXEDRCx4: Downloading webpage
# [download] Destination: Hrudayama - Lyrical | Major Telugu | Adivi Sesh | Saiee M Manjrekar | Sid Sriram | Sricharan Pakala.mp3
# [download] 100% of 3.71MiB in 01:19
# Download complete... Hrudayama - Lyrical | Major Telugu | Adivi Sesh | Saiee M Manjrekar | Sid Sriram | Sricharan Pakala.mp3

# %%
import subprocess
  
# convert mp3 to wav file
subprocess.call(['ffmpeg', '-i', '/content/akkoi.mp3',
                 'converted_to_wav_file.wav'])
# Out:
# 0

# %%
import subprocess

# %%
# !pip install pydub
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# import required modules
from os import path
from pydub import AudioSegment

# assign files
input_file = "/content/mudhal_nee.mp3"
output_file = "/content/mudhal_nee.wav"

# convert mp3 file to wav file
subprocess.call(['ffmpeg', '-i', '/content/ramu.mp3',
                 'mudhal_nee.wav'])
wav_obj = wave.open('/content/mudhal_nee.wav', 'rb')
sample_freq = wav_obj.getframerate()

n_samples = wav_obj.getnframes()

t_audio = n_samples/sample_freq

n_channels = wav_obj.getnchannels()

signal_wave = wav_obj.readframes(n_samples)
signal_array = np.frombuffer(signal_wave, dtype=np.int16)
l_channel = signal_array[0::2]
r_channel = signal_array[1::2]
times = np.linspace(0, n_samples/sample_freq, num=n_samples)
import matplotlib.pyplot as plt
def sining(tim,times):
  if abs(math.sin(10*math.pi*tim/(times[-1]))) <0.2:
    return 0.2
  else:
    return abs(math.sin(10*math.pi*tim/(times[-1])))
def cosing(tim,times):
  if abs(math.cos(10*math.pi*tim/(times[-1]))) <0.2:
    return 0.2
  else:
    return abs(math.cos(10*math.pi*tim/(times[-1])))

mock = signal_array.copy()
temp = mock[0::2]
temp2 = mock[1::2]
k  = []
for i in range(len(temp)):
  k.append(temp[i]*(sining(times[i],times)))

plt.figure(figsize=(15, 5))
plt.plot(times, k)
plt.title('k Channel')
plt.ylabel('Signal Value')
plt.xlabel('Time (s)')
plt.xlim(0, t_audio)
plt.show()

k2 = []

for i in range(len(temp2)):
  k2.append(temp2[i]*(cosing(times[i],times)))


plt.figure(figsize=(15, 5))
plt.plot(times, k2)
plt.title('k2 Channel')
plt.ylabel('Signal Value')
plt.xlabel('Time (s)')
plt.xlim(0, t_audio)
plt.show()
mock[0::2] = k
mock[1::2] = k2
import wave
mock_buffer = mock.tobytes()
with wave.open("/content/mudhal_nee.wav", "rb") as handle:
    params = handle.getparams()
    # only read the first 10 seconds of audio
    frames = handle.readframes(len(times))
    print(handle.tell())

print(params)
params = list(params)
params[3] = len(frames)
print(params)

with wave.open("/content/mudhal_nee_8d.wav", "wb") as handle:
    handle.setparams(params)
    handle.writeframes(mock_buffer)


#read wav file to an audio-segment
song = AudioSegment.from_wav("/content/mudhal_nee_8d.wav")

#export audio segment to mp3
song.export("/content/nuvvena.mp3", format="mp3")
# Out:
# 2774016
# _wave_params(nchannels=2, sampwidth=2, framerate=44100, nframes=2774016, comptype='NONE', compname='not compressed')
# [2, 2, 44100, 11096064, 'NONE', 'not compressed']
# <_io.BufferedRandom name='/content/nuvvena.mp3'>

# %%
#read wav file to an audio-segment
song = AudioSegment.from_wav("/content/mudhal_nee_8d.wav")

#export audio segment to mp3
song.export("/content/song3_8d3.mp3", format="mp3")
# Out:
# <_io.BufferedRandom name='/content/song3_8d3.mp3'>

# %% [markdown]
# #visualising normal songs

# %%
import youtube_dl
def run():
    video_url = input("please enter youtube video url:")
    video_info = youtube_dl.YoutubeDL().extract_info(
        url = video_url,download=False
    )
    filename = input()
    filename = filename + ".mp3"
    options={
        'format':'bestaudio/best',
        'keepvideo':False,
        'outtmpl':filename,
    }

    with youtube_dl.YoutubeDL(options) as ydl:
        ydl.download([video_info['webpage_url']])

    print("Download complete... {}".format(filename))

if __name__=='__main__':
    run()
# Out:
# please enter youtube video url:https://www.youtube.com/watch?v=h6sRLvmaeWg
# [youtube] h6sRLvmaeWg: Downloading webpage
# mock
# [youtube] h6sRLvmaeWg: Downloading webpage
# [download] Destination: mock.mp3
# [download] 100% of 5.35MiB in 01:13
# Download complete... mock.mp3

# %%
import IPython
IPython.display.Audio("song3_8d3.mp3")
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# #male female mock

# %% [markdown]
# *   create  a list with 0.4 and 1
# *   multiply
